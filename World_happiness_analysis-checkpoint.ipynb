# %% [markdown]
# World Happiness Report Project
# Project Description
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# What is Dystopia?
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# What are the residuals?
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average life evaluations. These residuals have an average value of approximately zero over the whole set of countries.
#
# What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country.
# The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country.
# The Dystopia Residual is already provided in the dataset.
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.
# You need to predict the happiness score considering all the other factors mentioned in the dataset.
# Dataset Link-
# https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head(15)
# Out:
#           Country                           Region  Happiness Rank  \
# 0     Switzerland                   Western Europe               1
# 1         Iceland                   Western Europe               2
# 2         Denmark                   Western Europe               3
# 3          Norway                   Western Europe               4
# 4          Canada                    North America               5
# 5         Finland                   Western Europe               6
# 6     Netherlands                   Western Europe               7
# 7          Sweden                   Western Europe               8
# 8     New Zealand        Australia and New Zealand               9
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# 11     Costa Rica      Latin America and Caribbean              12
# 12        Austria                   Western Europe              13
# ...

# %%
df.tail(15)
# Out:
#                       Country                           Region  \
# 143                     Niger               Sub-Saharan Africa
# 144                  Cambodia                Southeastern Asia
# 145                  Tanzania               Sub-Saharan Africa
# 146                Madagascar               Sub-Saharan Africa
# 147  Central African Republic               Sub-Saharan Africa
# 148                      Chad               Sub-Saharan Africa
# 149                    Guinea               Sub-Saharan Africa
# 150               Ivory Coast               Sub-Saharan Africa
# 151              Burkina Faso               Sub-Saharan Africa
# 152               Afghanistan                    Southern Asia
# 153                    Rwanda               Sub-Saharan Africa
# 154                     Benin               Sub-Saharan Africa
# 155                     Syria  Middle East and Northern Africa
# 156                   Burundi               Sub-Saharan Africa
# ...

# %% [markdown]
# # Exploratary Data Analysis- EDA

# %%
# Checking daimention of data

# %%
df.shape
# Out:
# (158, 12)

# %%
# In this dataset 158 rows and 12 columns out of which 1 is target variable and 11 columns are independent variables
# happiness rank columns is label and remaining other columns are features

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# columns name in list format

# %%
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
# checking the data types of each columns

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# checking the null value

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
# in this data there is no null value

# %%
# let's visulize null value is using heatmap

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Checking the unique value in target columns

# %%
df['Dystopia Residual'].unique()
# Out:
# array([2.51738, 2.70201, 2.49204, 2.46531, 2.45176, 2.61955, 2.4657 ,
#        2.37119, 2.26425, 2.26646, 3.08854, 3.17728, 2.5332 , 3.60214,
#        2.51011, 3.26001, 1.96961, 1.9757 , 2.41484, 2.24743, 1.96994,
#        2.47489, 3.19131, 1.88501, 2.84848, 2.11569, 2.67585, 1.55674,
#        2.21126, 2.836  , 2.67782, 2.32142, 2.85737, 2.31945, 2.43872,
#        2.12367, 1.6488 , 2.32323, 1.87634, 2.79094, 2.26882, 3.035  ,
#        2.74255, 2.23741, 2.24639, 1.68435, 2.21978, 2.53942, 1.73797,
#        2.02518, 2.82334, 3.10712, 2.18896, 2.24729, 1.61583, 2.44649,
#        2.32407, 2.5945 , 2.1309 , 1.86565, 1.88541, 2.75414, 2.09066,
#        2.27394, 2.32038, 1.59888, 1.88931, 2.43209, 2.76579, 1.86984,
#        1.76145, 0.65429, 1.58782, 1.86399, 2.20173, 2.08528, 2.2327 ,
#        2.89319, 1.63794, 2.00073, 3.10709, 1.87996, 2.10017, 1.8604 ,
#        2.6343 , 1.93129, 2.025  , 1.26462, 1.62215, 1.7536 , 2.11032,
# ...

# %%
# Checking the total unique value count in target columns

# %%
df['Dystopia Residual'].nunique()
# Out:
# 158

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
# in this inforamation we found that country and region have objet data type in catagorial value 
# but we have no need to convert catagorial columns because its not  consider in skewness

# %%
# Statistical summary of numerical columns

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # The summary of dataset looks perfect since there is no negetive or invalid value present
# # Observe the following
# 1- counts of all columns data is same it means that there no null value in dataset
# 2- no negetive or invalid value found in dataset it means dataset looks perfect
# 3- the mean value greater then median 50% value in hstandard error, trust and generosity columns that means the data skewed to the right
# 4- when mean value of happiness rank, economy, family,health,freedom,Dystopia residual columns less then median that means data is skewed in left
# 5- we observe that there is regular increase in same value in 25%,50%,76% and max value

# %%
# Data Visualization

# %%
sns.lmplot(x='Dystopia Residual', y='Happiness Score', data=df, palette='colorblind')

# %%
# Dropping categorical data that are not contributing to the label prediction

# %%
df1=df.drop(['Country','Region','Happiness Rank'],axis=1)

# %%
df1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Checking the correlation between target variable and independent variable

# %%
cor=df1.corr()
cor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
# let's visulize corelation via heatmap

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (15,6))
sns.heatmap(cor, linewidths=0.1, fmt='g', linecolor='black', annot=True,cmap='Blues_r')
#plt.ysticks(rotation=0)
plt.show()

# %%
# Happiness Score and Standard Error that indicates that they are negatively correlated to each other.
# The dark black colors indicate that they are very high negatively correlated to each other.
# Economy,family,health,indicate the positive correlation between the two columns.

# %%
# correlation visulized via pairplot

# %%
sns.pairplot(df1)
plt.show()

# %%
# checking for data distribution

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (20,15), facecolor = 'white')
plotnumber = 1

for column in df1:
    if plotnumber <12:
        ax = plt.subplot (3,4, plotnumber)
        sns.distplot (df1 [column])
        plt.xlabel (column, fontsize =20)
    plotnumber +=1
plt.tight_layout()

# %%
# most of the features have positive skewness
# some features have multimodel

# %%
# checking outliers

# %%
plt.figure (figsize = (20,25))
graph = 1

for column in df1:
    if graph <=12: 
        plt.subplot (4,3, graph)
        ax = sns.boxplot (data = df1[column],)
        plt.xlabel (column, fontsize = 15)
    graph +=1
plt.show()

# %%
# standard error ,trust,generosity,family and dystopia residdual having outlieres im data 
# the data distribution is unbalanced
# box plot graph confirm that there is skewness in data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Score                158 non-null    float64
#  1   Standard Error                 158 non-null    float64
#  2   Economy (GDP per Capita)       158 non-null    float64
#  3   Family                         158 non-null    float64
#  4   Health (Life Expectancy)       158 non-null    float64
#  5   Freedom                        158 non-null    float64
#  6   Trust (Government Corruption)  158 non-null    float64
#  7   Generosity                     158 non-null    float64
#  8   Dystopia Residual              158 non-null    float64
# dtypes: float64(9)
# memory usage: 11.2 KB

# %%
# checking for skewness score

# %%
df1.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
# from the skew() method we can see certain columns that are not in the acceptable range of -0.5 to 0.5. 
# that indicates that we have outliers present in our ata set will need to be treated.

# %%
#remove outliers

# %%
from scipy.stats import zscore

z_score = zscore (df1[['Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']])
abs_z_score = np.abs(z_score)
filtering_entry = (abs_z_score < 3).all(axis=1)
dfz = df1[filtering_entry]
dfz
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
# With the help of ZScore Method we are able to detect the skewbess and have removed them from our data set

# %%
dfz.skew()
# Out:
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
dfz.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
# Splitting the dataset into 2 variables namely 'x','y' for feature and label

# %%
x=dfz.drop('Happiness Score', axis=1)
y=dfz['Happiness Score']

# %%
x.shape
# Out:
# (149, 8)

# %%
y.shape
# Out:
# (149,)

# %%
x.head()
# Out:
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# 2     0.34139            2.49204
# 3     0.34699            2.46531
# 4     0.45811            2.45176

# %%
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
#Using Quantile transformer for skewness removal

# %%
from sklearn.preprocessing import QuantileTransformer
qt = QuantileTransformer()
np_array = qt.fit_transform(x)
np_array
# Out:
# array([[0.12837838, 0.96621622, 0.97972973, ..., 0.97297297, 0.74324324,
#         0.7972973 ],
#        [0.68243243, 0.86486486, 1.        , ..., 0.62837838, 0.92567568,
#         0.85810811],
#        [0.10810811, 0.88513514, 0.98648649, ..., 0.99324324, 0.82432432,
#         0.77702703],
#        ...,
#        [0.0472973 , 0.11486486, 0.        , ..., 0.45945946, 0.85810811,
#         0.39189189],
#        [0.23648649, 0.10810811, 0.00675676, ..., 0.35810811, 0.37837838,
#         0.15540541],
#        [0.97972973, 0.00675676, 0.04054054, ..., 0.46621622, 0.4527027 ,
#         0.26351351]])

# %%
x.columns
# Out:
# Index(['Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#converting array into dataframe

# %%
xt = pd.DataFrame(np_array, columns = ['Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual'])

# %%
xt.head()
# Out:
#    Standard Error  Economy (GDP per Capita)    Family  \
# 0        0.128378                  0.966216  0.979730
# 1        0.682432                  0.864865  1.000000
# 2        0.108108                  0.885135  0.986486
# 3        0.344595                  0.979730  0.966216
# 4        0.168919                  0.891892  0.959459
#
#    Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                  0.945946  0.993243                       0.972973
# 1                  0.959459  0.912162                       0.628378
# 2                  0.804054  0.959459                       0.993243
# 3                  0.831081  1.000000                       0.925676
# 4                  0.885135  0.925676                       0.912162
#
#    Generosity  Dystopia Residual
# 0    0.743243           0.797297
# 1    0.925676           0.858108
# 2    0.824324           0.777027
# 3    0.844595           0.750000
# 4    0.932432           0.736486

# %%
plt.figure(figsize = (20,15), facecolor = 'white')
plotnumber = 1 

for column in xt:
    if plotnumber <12: 
        ax = plt.subplot (3,4, plotnumber)
        sns.distplot (xt [column])
        plt.xlabel (column, fontsize =20)
    plotnumber +=1
plt.tight_layout()

# %%
# All the figure after removal of outliers most of have positive correletion

# %%
sns.countplot(y)
# Out:
# <Axes: ylabel='count'>

# %%
# Modelling

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)


Lin_reg_model = LinearRegression()
Lin_reg_model.fit(x_train, y_train)

print('Intercept:', Lin_reg_model.intercept_)
print('Coefficients:', Lin_reg_model.coef_)
# Out:
# Intercept: 5.429597953783009
# Coefficients: [-1.36046648e-05  3.86692232e-01  2.51046163e-01  2.45087141e-01
#   1.50300768e-01  1.13003985e-01  1.19505246e-01  5.23913745e-01]

# %%
# We have used 5 regression algorithm namely linear regression, support vector regression, decision tree regressor, random forest regressor and k neighbors regressor. 
# Used the sklearn page to use the correct parameters for each of the models.

# %%
# Linear regression

# %%
for i in range (0,100):
    x_train,x_test,y_train,y_test = train_test_split (xt, y, test_size = 0.2, random_state = i)
    lr.fit (x_train, y_train)
    pred_train = lr.predict (x_train)
    pred_test = lr.predict (x_test)
    print (f"At random state {i}, the training accuracy is: {r2_score (y_train, pred_train)}")
    print (f"At random state {i}, the testing accuracy is: {r2_score (y_test, pred_test)}")
    print ('\n')
# Out:
# At random state 0, the training accuracy is: 0.9696360733758311
# At random state 0, the testing accuracy is: 0.9769786740891904
#
#
# At random state 1, the training accuracy is: 0.9694076052515498
# At random state 1, the testing accuracy is: 0.9799512840397112
#
#
# At random state 2, the training accuracy is: 0.972316099026867
# At random state 2, the testing accuracy is: 0.9648699375897241
#
#
# At random state 3, the training accuracy is: 0.9731842591593377
# At random state 3, the testing accuracy is: 0.9590921073109651
#
#
# At random state 4, the training accuracy is: 0.966406595188511
# At random state 4, the testing accuracy is: 0.9798573864048267
#
#
# At random state 5, the training accuracy is: 0.9714638826107237
# At random state 5, the testing accuracy is: 0.9660091798669583
#
#
# At random state 6, the training accuracy is: 0.971054048983829
# At random state 6, the testing accuracy is: 0.9701839914922225
#
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
Scaler= StandardScaler()
x=pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)
x
# Out:
#      Standard Error  Economy (GDP per Capita)    Family  \
# 0         -0.866786                  1.381916  1.357879
# 1          0.185669                  1.138324  1.567882
# 2         -0.926089                  1.198220  1.401974
# 3         -0.531687                  1.543526  1.283947
# 4         -0.765327                  1.200315  1.250726
# ..              ...                       ...       ...
# 144        0.369294                 -1.026255 -0.945943
# 145       -0.214450                 -1.562163 -0.624365
# 146       -1.100427                 -1.402596 -2.811354
# 147       -0.691734                 -1.488379 -2.608163
# 148        2.882182                 -2.190139 -2.361154
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 0                    1.235390  1.583704                       2.472255
# 1                    1.261541  1.338953                       0.009247
# 2                    0.962900  1.476027                       3.036747
# ...

# %%
 # Finding Variance inflation factor in eached scaled columns

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]= [variance_inflation_factor(x.values,1) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF values                       Features
# 0    4.200848                 Standard Error
# 1    4.200848       Economy (GDP per Capita)
# 2    4.200848                         Family
# 3    4.200848       Health (Life Expectancy)
# 4    4.200848                        Freedom
# 5    4.200848  Trust (Government Corruption)
# 6    4.200848                     Generosity
# 7    4.200848              Dystopia Residual

# %%
# based on vif values all columns having same effect in data set
y.value_counts()
# Out:
# Happiness Score
# 5.192    2
# 7.587    1
# 4.739    1
# 4.874    1
# 4.867    1
#         ..
# 5.889    1
# 5.878    1
# 5.855    1
# 5.848    1
# 2.905    1
# Name: count, Length: 148, dtype: int64

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from scipy.stats import zscore
import math

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder

# %%
# Linear Regression

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
predLR = LR.predict(x_test)
print(accuracy_score,y_test,predLR)
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# <function accuracy_score at 0x000001C6F1544EA0> 151    3.587
# 92     5.007
# 56     5.828
# 80     5.194
# 87     5.102
# 108    4.694
# 94     4.959
# 55     5.833
# 46     5.984
# 61     5.759
# 5      7.406
# 16     6.946
# 96     4.898
# 14     7.119
# 60     5.770
# 34     6.411
# 76     5.286
# 30     6.505
# 69     5.548
# 36     6.302
# 123    4.436
# 150    3.655
# 32     6.477
# 135    4.077
# 114    4.610
# 19     6.901
# 53     5.855
# 50     5.890
# 93     4.971
# 105    4.786
# 132    4.252
# 101    4.857
# 44     5.995
# 141    3.904
# 29     6.574
# 42     6.123
# 110    4.681
# 121    4.512
# 17     6.940
# 117    4.550
# 149    3.656
# 72     5.429
# 78     5.253
# 18     6.937
# 4      7.427
# Name: Happiness Score, dtype: float64 [3.58684938 5.00706433 5.82829635 5.19382984 5.10164261 4.69397009
#  4.95936877 5.83263115 5.98378637 5.75857095 7.40606959 6.94626334
#  4.89748748 7.11955338 5.77042796 6.41120347 5.28635484 6.50502568
# ...

# %%
# Support Value Regression

# %%
svr = SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
svr.fit(x_train, y_train)
predSVR = svr.predict(x_test)
print(accuracy_score,y_test,predSVR)
print(confusion_matrix(y_test,predSVR))
print(classification_report(y_test,predSVR))
# Out:
# <function accuracy_score at 0x000001C6F1544EA0> 151    3.587
# 92     5.007
# 56     5.828
# 80     5.194
# 87     5.102
# 108    4.694
# 94     4.959
# 55     5.833
# 46     5.984
# 61     5.759
# 5      7.406
# 16     6.946
# 96     4.898
# 14     7.119
# 60     5.770
# 34     6.411
# 76     5.286
# 30     6.505
# 69     5.548
# 36     6.302
# 123    4.436
# 150    3.655
# 32     6.477
# 135    4.077
# 114    4.610
# 19     6.901
# 53     5.855
# 50     5.890
# 93     4.971
# 105    4.786
# 132    4.252
# 101    4.857
# 44     5.995
# 141    3.904
# 29     6.574
# 42     6.123
# 110    4.681
# 121    4.512
# 17     6.940
# 117    4.550
# 149    3.656
# 72     5.429
# 78     5.253
# 18     6.937
# 4      7.427
# Name: Happiness Score, dtype: float64 [3.85020053 5.37681688 5.56713529 5.2422935  5.3293173  4.94372917
#  5.30992679 5.60972911 5.70887423 5.49112091 7.2809645  6.8347511
#  5.27491273 6.54400884 5.51734094 6.06715901 5.40384804 6.11147957
# ...

# %%
# Decision tree regression

# %%
dtr = DecisionTreeRegressor(criterion="poisson", random_state=111)
dtr.fit(x_train, y_train)
predDTR = dtr_model.predict(x_test)
print(accuracy_score,y_test,predDTR)
print(confusion_matrix(y_test,predDTR))
print(classification_report(y_test,predDTR))
# Out:
# <function accuracy_score at 0x000001C6F1544EA0> 151    3.587
# 92     5.007
# 56     5.828
# 80     5.194
# 87     5.102
# 108    4.694
# 94     4.959
# 55     5.833
# 46     5.984
# 61     5.759
# 5      7.406
# 16     6.946
# 96     4.898
# 14     7.119
# 60     5.770
# 34     6.411
# 76     5.286
# 30     6.505
# 69     5.548
# 36     6.302
# 123    4.436
# 150    3.655
# 32     6.477
# 135    4.077
# 114    4.610
# 19     6.901
# 53     5.855
# 50     5.890
# 93     4.971
# 105    4.786
# 132    4.252
# 101    4.857
# 44     5.995
# 141    3.904
# 29     6.574
# 42     6.123
# 110    4.681
# 121    4.512
# 17     6.940
# 117    4.550
# 149    3.656
# 72     5.429
# 78     5.253
# 18     6.937
# 4      7.427
# Name: Happiness Score, dtype: float64 [3.995 4.8   5.975 4.565 6.295 4.507 5.14  6.298 6.455 7.278 7.378 6.75
#  4.507 6.983 5.689 6.298 5.824 7.187 4.677 5.848 4.507 4.874 5.889 4.194
#  4.507 6.853 5.716 6.269 4.507 5.129 4.369 6.295 6.455 4.874 6.786 5.824
# ...

# %%
# Random forest regressor

# %%
rfr = RandomForestRegressor(max_depth=2, max_features="sqrt")
rfr.fit(x_train, y_train)
predRFR = rfr.predict(x_test)
print(accuracy_score,y_test,predRFR)
print(confusion_matrix(y_test,predRFR))
print(classification_report(y_test,predRFR))
# Out:
# <function accuracy_score at 0x000001C6F1544EA0> 151    3.587
# 92     5.007
# 56     5.828
# 80     5.194
# 87     5.102
# 108    4.694
# 94     4.959
# 55     5.833
# 46     5.984
# 61     5.759
# 5      7.406
# 16     6.946
# 96     4.898
# 14     7.119
# 60     5.770
# 34     6.411
# 76     5.286
# 30     6.505
# 69     5.548
# 36     6.302
# 123    4.436
# 150    3.655
# 32     6.477
# 135    4.077
# 114    4.610
# 19     6.901
# 53     5.855
# 50     5.890
# 93     4.971
# 105    4.786
# 132    4.252
# 101    4.857
# 44     5.995
# 141    3.904
# 29     6.574
# 42     6.123
# 110    4.681
# 121    4.512
# 17     6.940
# 117    4.550
# 149    3.656
# 72     5.429
# 78     5.253
# 18     6.937
# 4      7.427
# Name: Happiness Score, dtype: float64 [4.50561749 5.00412708 5.56504062 4.94008512 5.49064826 4.86208827
#  5.03998977 5.85690294 5.68297513 5.4827644  6.89686817 6.55617951
#  4.88833188 6.55432063 5.30725022 5.76613804 5.29252039 6.01590483
# ...

# %%
# Knn regressor

# %%
knn = KNeighborsRegressor(n_neighbors=2, algorithm='kd_tree')
knn.fit(x_train, y_train)
predKNN = knr_model.predict(x_test)
print(accuracy_score,y_test,predKNN)
print(confusion_matrix(y_test,predKNN))
print(classification_report(y_test,predKNN))
# Out:
# <function accuracy_score at 0x000001C6F1544EA0> 151    3.587
# 92     5.007
# 56     5.828
# 80     5.194
# 87     5.102
# 108    4.694
# 94     4.959
# 55     5.833
# 46     5.984
# 61     5.759
# 5      7.406
# 16     6.946
# 96     4.898
# 14     7.119
# 60     5.770
# 34     6.411
# 76     5.286
# 30     6.505
# 69     5.548
# 36     6.302
# 123    4.436
# 150    3.655
# 32     6.477
# 135    4.077
# 114    4.610
# 19     6.901
# 53     5.855
# 50     5.890
# 93     4.971
# 105    4.786
# 132    4.252
# 101    4.857
# 44     5.995
# 141    3.904
# 29     6.574
# 42     6.123
# 110    4.681
# 121    4.512
# 17     6.940
# 117    4.550
# 149    3.656
# 72     5.429
# 78     5.253
# 18     6.937
# 4      7.427
# Name: Happiness Score, dtype: float64 [3.92   4.943  6.1815 4.582  5.8195 4.789  4.5945 5.6605 6.123  5.2815
#  7.557  7.5545 4.687  7.3805 5.863  5.8865 5.196  6.0765 5.8865 7.008
#  3.8185 3.992  7.006  4.823  4.092  7.5545 5.4915 5.6295 4.818  4.937
# ...

# %%
# Evalution

# %%
mse_linear = mean_squared_error(y_test, pred_linear)
rmse_linear = mean(mse_linear)
print(f"RMSE of Linear Regression is: ", rmse_linear)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 2
#       1 mse_linear = mean_squared_error(y_test, pred_linear)
# ----> 2 rmse_linear = mean(mse_linear)
#       3 print(f"RMSE of Linear Regression is: ", rmse_linear)
#
# NameError: name 'mean' is not defined

# %%
from sklearn.model_selection import cross_val_score

score= cross_val_score(LR,x,y)
print(score)
print(score.mean)
print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.99999943 0.99999847 0.99999831 0.99999509 0.99999933]
# <built-in method mean of numpy.ndarray object at 0x000001C6F307B5D0>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[172], line 6
#       4 print(score)
#       5 print(score.mean)
# ----> 6 print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predLR)-score.mean())
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
score= cross_val_score(dtr,x,y)
print(score)
print(score.mean)
print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predDTR)-score.mean())
# Out:
# [ -5.44902053  -8.71815472  -5.54353249 -11.17668203  -5.6197031 ]
# <built-in method mean of numpy.ndarray object at 0x000001C6F3098030>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[174], line 4
#       2 print(score)
#       3 print(score.mean)
# ----> 4 print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predDTR)-score.mean())
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
score= cross_val_score(svr,x,y)
print(score)
print(score.mean)
print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predSVR)-score.mean())
# Out:
# [ -5.94616009  -3.79254289  -0.77198484 -10.70367613  -8.622202  ]
# <built-in method mean of numpy.ndarray object at 0x000001C6F4A36910>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[175], line 4
#       2 print(score)
#       3 print(score.mean)
# ----> 4 print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predSVR)-score.mean())
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
score= cross_val_score(rfr,x,y)
print(score)
print(score.mean)
print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predRFR)-score.mean())
# Out:
# [-21.97173554  -5.83709304  -0.64651251  -7.26203283 -13.88813504]
# <built-in method mean of numpy.ndarray object at 0x000001C6F30088D0>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 4
#       2 print(score)
#       3 print(score.mean)
# ----> 4 print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predRFR)-score.mean())
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
score= cross_val_score(knn,x,y)
print(score)
print(score.mean)
print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predKNN)-score.mean())
# Out:
# [-6.39217894 -5.0749247  -4.42253053 -7.4403167  -4.91827972]
# <built-in method mean of numpy.ndarray object at 0x000001C6F4370810>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 4
#       2 print(score)
#       3 print(score.mean)
# ----> 4 print("Differance between accuracy score and cross validation score is-", accuracy_score(y_test,predKNN)-score.mean())
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
# ...

# %%
# Hyper Parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

parameters= {'criterion' : ['gini','entropy'],
           'random_state' : [10,50,1000],
           'max_depth' : [0,10,20],
           'n_jobs' : [-2,-1,1],
           'n_estimators' : [50,100,200,300]}

# %%
GCV= []
GCV = GridSearchCV (LogisticRegression(), parameters, cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 GCV.fit(x_train,y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1018, in BaseSearchCV.fit(self, X, y, **params)
#    1012     results = self._format_results(
#    1013         all_candidate_params, n_splits, all_out, all_more_results
#    1014     )
#    1016     return results
# -> 1018 self._run_search(evaluate_candidates)
# ...

# %%
GCV.best_params_

# %%
Final_model= ExtraTreesClassifier(criterion = 'entropy', max_depth = 10, n_estimaters = 100, n_jobs = -2, random_state =50 )
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)

# %%
Final_model= ExtraTreesClassifier(criterion = 'entropy', max_depth = 10, n_estimaters = 100, n_jobs = -2, random_state =50 )
Final_model.fit(x_train, y_train)
pred = Final_model.predict(x_test)
acc = accuracy_score(y_test,pred)
print(acc*100)

# %%
#  Plotting ROC and compare AUC for all model used

# %%
from sklearn import datasets
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection, svm
from sklearn.metrics import plot_roc_curve

from sklearn import datasets, model_selection, svm, metrics
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[191], line 5
#       3 import matplotlib.pyplot as plt
#       4 from sklearn import datasets, model_selection, svm
# ----> 5 from sklearn.metrics import plot_roc_curve
#       7 from sklearn import datasets, model_selection, svm, metrics
#       8 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'plot_roc_curve' from 'sklearn.metrics' (C:\Users\Hiren Kareliya\anaconda3\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
disp = plot_roc_curv(ET,x_test,y_test)
plot_roc_curv(RFC,X-test, y_test,ax=disp.ax_)
plot_roc_curv(LR,X-test, y_test,ax=disp.ax_)
plot_roc_curv(SVC,X-test, y_test,ax=disp.ax_)
plot_roc_curv(ABC,X-test, y_test,ax=disp.ax_)
plot_roc_curv(GB,X-test, y_test,ax=disp.ax_)
plot_roc_curv(BC,X-test, y_test,ax=disp.ax_)


plt.legend(prop={'size':11}, loc = 'lower right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 disp = plot_roc_curv(ET,x_test,y_test)
#       2 plot_roc_curv(RFC,X-test, y_test,ax=disp.ax_)
#       3 plot_roc_curv(LR,X-test, y_test,ax=disp.ax_)
#
# NameError: name 'plot_roc_curv' is not defined

# %%
# Saving the Model

# %%
import joblib
joblib.dump(Final_model, "Redwine_quality_analysis.pkl")

# %%
# Predicting the save model

# %%
model = joblib.load("World_happiness_analysis.pkl")


#Prediction

prediction= model.predict(x_test)
prediction
